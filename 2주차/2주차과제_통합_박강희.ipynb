# %%
# titanic.csv 파일을 불러오고 데이터 확인
import pandas as pd

# 데이터 불러오기
df = pd.read_csv(r"C:\Users\Administrator\Desktop\수업\2과제\titanic.csv")

# 데이터 확인
print(df.head())

# 데이터 확인
print(df.info())

# 데이터 확인
print(df.describe())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#수치형과 범주형을 분리
CATEGORY_COLS = ['Pclass', 'Sex', 'Embarked']
NUMERIC_COLS = ['Age', 'SibSp', 'Parch', 'Fare']

# %%
#결측치확인
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Age 결측치는 평균값으로 대치
df['Age'] = df['Age'].fillna(df['Age'].mean())

#Embarked 결측치는  대치
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
#결측치확인
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install scikit-learn
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/68/c7/4e956281a077f4835458c3f9656c666300282d5199039f26d9de1dabd9be/scikit_learn-1.7.0-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/7d/4f/1195bbac8e0c2acc5f740661631d8d750dc38d4a32b23ee5df3cde6f4e0d/joblib-1.5.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/32/d5/f9a850d79b0851d1d4ef6456097579a9005b31fea68726a4ae5f2d82ddd9/threadpoolctl-3.6.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.7 MB 5.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/10.7 MB 4.0 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/10.7 MB 4.8 MB/s eta 0:00:03
# ...

# %%
# 수치형변수에 대해서 scaling 진행
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[NUMERIC_COLS] = scaler.fit_transform(df[NUMERIC_COLS])

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex       Age  \
# 0                            Braund, Mr. Owen Harris    male -0.592481
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.638789
# 2                             Heikkinen, Miss. Laina  female -0.284663
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.407926
# 4                           Allen, Mr. William Henry    male  0.407926
#
#       SibSp     Parch            Ticket      Fare Cabin Embarked
# 0  0.432793 -0.473674         A/5 21171 -0.502445   NaN        S
# 1  0.432793 -0.473674          PC 17599  0.786845   C85        C
# 2 -0.474545 -0.473674  STON/O2. 3101282 -0.488854   NaN        S
# 3  0.432793 -0.473674            113803  0.420730  C123        S
# ...

# %%
# 범주형 변수에 대해서 label encoding 진행
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df[CATEGORY_COLS] = df[CATEGORY_COLS].apply(encoder.fit_transform)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       2
# 1            2         1       0
# 2            3         1       2
# 3            4         1       0
# 4            5         0       2
#
#                                                 Name  Sex       Age     SibSp  \
# 0                            Braund, Mr. Owen Harris    1 -0.592481  0.432793
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  0.638789  0.432793
# 2                             Heikkinen, Miss. Laina    0 -0.284663 -0.474545
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  0.407926  0.432793
# 4                           Allen, Mr. William Henry    1  0.407926 -0.474545
#
#       Parch            Ticket      Fare Cabin  Embarked
# 0 -0.473674         A/5 21171 -0.502445   NaN         2
# 1 -0.473674          PC 17599  0.786845   C85         0
# 2 -0.473674  STON/O2. 3101282 -0.488854   NaN         2
# 3 -0.473674            113803  0.420730  C123         2
# ...

# %%
df[NUMERIC_COLS + CATEGORY_COLS]
# Out:
#           Age     SibSp     Parch      Fare  Pclass  Sex  Embarked
# 0   -0.592481  0.432793 -0.473674 -0.502445       2    1         2
# 1    0.638789  0.432793 -0.473674  0.786845       0    0         0
# 2   -0.284663 -0.474545 -0.473674 -0.488854       2    0         2
# 3    0.407926  0.432793 -0.473674  0.420730       0    0         2
# 4    0.407926 -0.474545 -0.473674 -0.486337       2    1         2
# ..        ...       ...       ...       ...     ...  ...       ...
# 886 -0.207709 -0.474545 -0.473674 -0.386671       1    1         2
# 887 -0.823344 -0.474545 -0.473674 -0.044381       0    0         2
# 888  0.000000  0.432793  2.008933 -0.176263       2    0         2
# 889 -0.284663 -0.474545 -0.473674 -0.044381       0    1         0
# 890  0.177063 -0.474545 -0.473674 -0.492378       2    1         1
#
# [891 rows x 7 columns]

# %%
# train, test 데이터 분리
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df[NUMERIC_COLS + CATEGORY_COLS], df['Survived'], test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((712, 7), (179, 7), (712,), (179,))

# %%
# 랜덤포레스트로 분류모델 생성
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# 성능평가
from sklearn.metrics import accuracy_score, classification_report

y_pred = model.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.8156424581005587

# %%
#감정분류

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
# 1. 데이터 불러오기
url = "https://raw.githubusercontent.com/ohgzone/file1/main/aihub_coupus.csv"
df = pd.read_csv(url)

# %%
# 2. 데이터 전처리
df = df.dropna()
X = df['문장']
y = df['감정']

# %%
# 감정 라벨 인코딩
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
# 3. 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
# 4. 벡터화
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# 5. 모델 학습
model = LogisticRegression(max_iter=1000)
model.fit(X_train_vec, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# 6. 평가
y_pred = model.predict(X_test_vec)
print("정확도:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# 정확도: 0.5153011814836336
#               precision    recall  f1-score   support
#
#           기쁨       0.73      0.72      0.73      1206
#           당황       0.50      0.45      0.47      1718
#           분노       0.48      0.49      0.49      1831
#           불안       0.51      0.56      0.53      1891
#           상처       0.42      0.46      0.44      1837
#           슬픔       0.54      0.48      0.51      1843
#
#     accuracy                           0.52     10326
#    macro avg       0.53      0.53      0.53     10326
# weighted avg       0.52      0.52      0.52     10326

# %%
# 7. 예측 함수
def predict_emotion(sentence):
    vec = vectorizer.transform([sentence])
    pred = model.predict(vec)[0]
    proba = model.predict_proba(vec)[0]
    emotion = le.inverse_transform([pred])[0]
    score = proba[pred]
    return emotion, score

# %%
sentence = "넌 정말 예쁜 사람이야!."
emotion, score = predict_emotion(sentence)
print(f"문장: {sentence}\n예측 감정: {emotion}\n신뢰도: {score:.2f}")
# Out:
# 문장: 넌 정말 예쁜 사람이야!.
# 예측 감정: 기쁨
# 신뢰도: 0.53
